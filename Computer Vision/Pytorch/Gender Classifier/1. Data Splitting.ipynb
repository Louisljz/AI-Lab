# %% [markdown]
# ## Mount Drive

# %%
from google.colab import drive
import os
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Newton AI-Face Recognition Project/Dataset/'
# Out:
# /content/drive/MyDrive/Newton AI-Face Recognition Project/Dataset

# %%
directory = '/content/drive/MyDrive/Newton AI-Face Recognition Project/Dataset/'

# %%
keys_path = os.path.join(directory, 'gender_classification.csv')
data_path = os.path.join(directory, 'images')

# %% [markdown]
# ## Load Image Keys

# %%
import pandas as pd

# %%
df_keys = pd.read_csv(keys_path)
df_keys.columns = ['File Name', 'Gender (M:1; F:0)']
df_keys
# Out:
#        File Name  Gender (M:1; F:0)
# 0     000041.jpg                  1
# 1     000044.jpg                  0
# 2     000047.jpg                  0
# 3     000050.jpg                  1
# 4     000063.jpg                  0
# ...          ...                ...
# 9995  202548.jpg                  0
# 9996  202554.jpg                  1
# 9997  202557.jpg                  0
# 9998  202566.jpg                  1
# 9999  202590.jpg                  1
#
# [10000 rows x 2 columns]

# %%
df_keys.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   File Name          10000 non-null  object
#  1   Gender (M:1; F:0)  10000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 156.4+ KB

# %%
print('Total number of Images: ', len(os.listdir(data_path)))
# Out:
# Total number of Images:  10000

# %% [markdown]
# ## Divide Image into Folders

# %%
import shutil

# %%
male_path = os.path.join(directory, 'Male')
female_path = os.path.join(directory, 'Female')

# %%
filenames = df_keys['File Name'].to_numpy()
keys = df_keys['Gender (M:1; F:0)'].to_numpy()
file_keys = dict(zip(filenames, keys))

# %%
def move(gender_path, name):
  source_path = os.path.join(data_path, name)
  dest_path = os.path.join(gender_path, name)
  shutil.move(source_path, dest_path)

# %%
for name in os.listdir(data_path):
  if file_keys[name] == 1:
    move(male_path, name)
  else:
    move(female_path, name)
