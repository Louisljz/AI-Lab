# %% [markdown]
# ## Mount Drive

# %%
from google.colab import drive
import os
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Newton AI-Face Recognition Project/Dataset/SPLIT'
# Out:
# /content/drive/MyDrive/Newton AI-Face Recognition Project/Dataset/SPLIT

# %%
directory = '/content/drive/MyDrive/Newton AI-Face Recognition Project/Dataset/SPLIT'

# %%
male_path = os.path.join(directory, 'Male')
female_path = os.path.join(directory, 'Female')

# %% [markdown]
# ## Data Visualization

# %%
import seaborn as sns

# %%
male_count = len(os.listdir(male_path))
female_count = len(os.listdir(female_path))

# %%
sns.barplot(x=['Male', 'Female'], y=[male_count, female_count])
# Out:
# <Axes: >

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
sex = random.choice(['Male', 'Female'])
main_path = os.path.join(directory, sex)
files = os.listdir(main_path)

idx = random.randint(0, len(files)-1)
filename = files[idx]
filepath = os.path.join(main_path, filename)

img = Image.open(filepath)
plt.imshow(img)
plt.title(sex)
plt.show()

# %%
np.array(img).shape
# Out:
# (218, 178, 3)
