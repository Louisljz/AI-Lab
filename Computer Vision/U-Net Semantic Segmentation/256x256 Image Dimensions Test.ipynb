# %% [markdown]
# ## Imports

# %%
from google.colab import drive
import os

import cv2
import matplotlib.pyplot as plt

import numpy as np
import random

from keras.utils import to_categorical, plot_model
from keras.models import Model, load_model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Dropout
from keras.callbacks import ModelCheckpoint
from keras.metrics import OneHotIoU

# %% [markdown]
# ## Load Pre-Processed Dataset

# %% [markdown]
# **Mount Drive and SetUp Paths**

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "enter path here.."
# Out:
# /content/drive/MyDrive/Indonesia AI/Computer Vision/Final Project

# %%
main_dir = "enter path here.."

org_images_train = os.path.join(main_dir, 'org_images_train')
org_images_val = os.path.join(main_dir, 'org_images_val')
anot_images_train = os.path.join(main_dir, 'anot_images_train')
anot_images_val = os.path.join(main_dir, 'anot_images_val')

# %% [markdown]
# **Load original images and annotations**

# %%
x_train = []
y_train = []
x_test = []
y_test = []

# %% [markdown]
# The Loaded images are having a dimension of 256x256, so we need to resize it to our desired dimensions (128x128).

# %%
def load_ori_images(img_dir, dataset, samples):
  files = sorted(os.listdir(img_dir))
  for i in range(samples):
    img_path = os.path.join(img_dir, files[i])
    image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    image = image/255 # normalize
    dataset.append(image)
  
  return np.array(dataset)

# %%
def load_anotations(img_dir, dataset, samples):
  files = sorted(os.listdir(img_dir))
  for i in range(samples):
    img_path = os.path.join(img_dir, files[i])
    image = np.load(img_path) # file format in .npy
    dataset.append(image) 

  return np.array(dataset)

# %% [markdown]
# Adjust the number of samples according to your hardware.

# %%
x_train = load_ori_images(org_images_train, x_train, 1000)
y_train = load_anotations(anot_images_train, y_train, 1000)
x_test = load_ori_images(org_images_val, x_test, 200)
y_test = load_anotations(anot_images_val, y_test, 200)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1000, 256, 256)
# (1000, 256, 256)
# (200, 256, 256)
# (200, 256, 256)

# %% [markdown]
# **Color the Annotations**

# %%
class_map = {
    'unlabeled':(0, 0, 0),
    'sky':(70, 130, 180),
    'building':(70, 70, 70),
    'pole':(153, 153, 153),
    'road':(128, 64, 128),
    'sidewalk':(244, 35, 232),
    'vegetation':(107, 142, 35),
    'car':( 0, 0, 142),
    'person':(220, 20, 60),
    'traffic sign':(220, 220, 0)
}

# %%
labels = list(class_map.keys())
unique_colors = list(class_map.values())

# %%
visualization = y_train[0].copy()
visualization = np.repeat(visualization.reshape(256, 256, 1), 3, axis=2)
# copy channel 1 value into channel 2 and 3
visualization = visualization.reshape(-1, 3)
print(visualization.shape)
# Out:
# (65536, 3)

# %%
for i in range(len(visualization)):
  visualization[i] = unique_colors[visualization[i][0]]
# replace index label with corresponding color

# %%
visualization = visualization.reshape(256, 256, 3)

# %%
fig, axes = plt.subplots(1,3,figsize=(15,5))
axes[0].imshow(x_train[0], cmap='gray')
axes[1].imshow(y_train[0])
axes[2].imshow(visualization)

# %% [markdown]
# **One-Hot Encoding for Annotations**

# %%
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1000, 256, 256)
# (1000, 256, 256, 10)
# (200, 256, 256)
# (200, 256, 256, 10)

# %% [markdown]
# ## UNet Architecture

# %%
def unet():
  inputs = Input((256, 256, 1)) # adjust input dims, channel will be 1 bcs input image is in grayscale.


  c1 = Conv2D(64, (3, 3), padding="same", activation="relu")(inputs)
  c1 = Conv2D(64, (3, 3), padding="same", activation="relu")(c1)
  p1 = MaxPooling2D((2, 2))(c1)

  c2 = Conv2D(128, (3, 3), padding="same", activation="relu")(p1)
  c2 = Conv2D(128, (3, 3), padding="same", activation="relu")(c2)
  p2 = MaxPooling2D((2, 2))(c2)

  c3 = Conv2D(256, (3, 3), padding="same", activation="relu")(p2)
  c3 = Conv2D(256, (3, 3), padding="same", activation="relu")(c3)
  p3 = MaxPooling2D((2, 2))(c3)

  c4 = Conv2D(512, (3, 3), padding="same", activation="relu")(p3)
  c4 = Conv2D(512, (3, 3), padding="same", activation="relu")(c4)
  d4 = Dropout(0.2)(c4)
  p4 = MaxPooling2D((2, 2))(d4)


  c5 = Conv2D(1024, (3, 3), padding="same", activation="relu")(p4)
  c5 = Conv2D(1024, (3, 3), padding="same", activation="relu")(c5)
  d5 = Dropout(0.2)(c5)
  

  u6 = Conv2D(512, (2, 2), padding="same", activation="relu")(UpSampling2D((2, 2))(d5))
  m6 = concatenate([d4, u6], axis=3)
  c6 = Conv2D(512, (3, 3), padding="same", activation="relu")(m6)
  c6 = Conv2D(512, (3, 3), padding="same", activation="relu")(c6)

  u7 = Conv2D(256, (2, 2), padding="same", activation="relu")(UpSampling2D((2, 2))(c6))
  m7 = concatenate([c3, u7], axis=3)
  c7 = Conv2D(256, (3, 3), padding="same", activation="relu")(m7)
  c7 = Conv2D(256, (3, 3), padding="same", activation="relu")(c7)

  u8 = Conv2D(128, (2, 2), padding="same", activation="relu")(UpSampling2D((2, 2))(c7))
  m8 = concatenate([c2, u8], axis=3)
  c8 = Conv2D(128, (3, 3), padding="same", activation="relu")(m8)
  c8 = Conv2D(128, (3, 3), padding="same", activation="relu")(c8)

  u9 = Conv2D(64, (2, 2), padding="same", activation="relu")(UpSampling2D((2, 2))(c8))
  m9 = concatenate([c1, u9], axis=3)
  c9 = Conv2D(64, (3, 3), padding="same", activation="relu")(m9)
  c9 = Conv2D(64, (3, 3), padding="same", activation="relu")(c9)


  outputs = Conv2D(10, (1,1), activation="softmax")(c9) # 10 no. of kernels bcs 10 classes

  model = Model(inputs, outputs)
  return model

# %%
model = unet()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 64  640         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 64  36928       ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 64  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 12  147584      ['conv2d_2[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0          ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 256)  590080      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0          ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 512)  2359808     ['conv2d_6[0][0]']
#
#  dropout (Dropout)              (None, 32, 32, 512)  0           ['conv2d_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0          ['dropout[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 1024  9438208     ['conv2d_8[0][0]']
#                                 )
#
#  dropout_1 (Dropout)            (None, 16, 16, 1024  0           ['conv2d_9[0][0]']
#                                 )
#
#  up_sampling2d (UpSampling2D)   (None, 32, 32, 1024  0           ['dropout_1[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 512)  2097664     ['up_sampling2d[0][0]']
#
#  concatenate (Concatenate)      (None, 32, 32, 1024  0           ['dropout[0][0]',
#                                 )                                 'conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 512)  4719104     ['concatenate[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 512)  2359808     ['conv2d_11[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 512)  0          ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 256)  524544      ['up_sampling2d_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 512)  0           ['conv2d_5[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 256)  1179904     ['concatenate_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 256)  590080      ['conv2d_14[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 25  0          ['conv2d_15[0][0]']
#                                 6)
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 12  131200      ['up_sampling2d_2[0][0]']
#                                 8)
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 25  0           ['conv2d_3[0][0]',
#                                 6)                                'conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 12  147584      ['conv2d_17[0][0]']
#                                 8)
#
#  up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 12  0          ['conv2d_18[0][0]']
#                                 8)
#
#  conv2d_19 (Conv2D)             (None, 256, 256, 64  32832       ['up_sampling2d_3[0][0]']
#                                 )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 12  0           ['conv2d_1[0][0]',
#                                 8)                                'conv2d_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 256, 256, 64  36928       ['conv2d_20[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 256, 256, 10  650         ['conv2d_21[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 31,031,178
# Trainable params: 31,031,178
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(model, to_file="unet_architecture.png", rankdir='TB', 
                          show_layer_names=False)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Training Model

# %%
callback = ModelCheckpoint(filepath="256 Image Size Experiment/256_model.h5", monitor="val_accuracy", mode="max", save_best_only=True, verbose=1)

# %% [markdown]
# Lower batch size if runtime crash, so GPU not that heavy.

# %%
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), batch_size=16, epochs=40, callbacks=[callback])
# Out:
# Epoch 1/40
# 63/63 [==============================] - ETA: 0s - loss: 1.8874 - accuracy: 0.3649
# Epoch 1: val_accuracy improved from -inf to 0.44260, saving model to 256_model.h5
# 63/63 [==============================] - 113s 1s/step - loss: 1.8874 - accuracy: 0.3649 - val_loss: 1.6686 - val_accuracy: 0.4426
# Epoch 2/40
# 63/63 [==============================] - ETA: 0s - loss: 1.6057 - accuracy: 0.4833
# Epoch 2: val_accuracy did not improve from 0.44260
# 63/63 [==============================] - 70s 1s/step - loss: 1.6057 - accuracy: 0.4833 - val_loss: 1.7646 - val_accuracy: 0.4044
# Epoch 3/40
# 63/63 [==============================] - ETA: 0s - loss: 1.5435 - accuracy: 0.4784
# Epoch 3: val_accuracy improved from 0.44260 to 0.47696, saving model to 256_model.h5
# 63/63 [==============================] - 74s 1s/step - loss: 1.5435 - accuracy: 0.4784 - val_loss: 1.5582 - val_accuracy: 0.4770
# Epoch 4/40
# 63/63 [==============================] - ETA: 0s - loss: 1.2720 - accuracy: 0.5691
# Epoch 4: val_accuracy improved from 0.47696 to 0.60283, saving model to 256_model.h5
# 63/63 [==============================] - 75s 1s/step - loss: 1.2720 - accuracy: 0.5691 - val_loss: 1.1794 - val_accuracy: 0.6028
# Epoch 5/40
# 63/63 [==============================] - ETA: 0s - loss: 1.0568 - accuracy: 0.6393
# Epoch 5: val_accuracy improved from 0.60283 to 0.65010, saving model to 256_model.h5
# 63/63 [==============================] - 75s 1s/step - loss: 1.0568 - accuracy: 0.6393 - val_loss: 1.0517 - val_accuracy: 0.6501
# Epoch 6/40
# 63/63 [==============================] - ETA: 0s - loss: 0.9438 - accuracy: 0.6781
# Epoch 6: val_accuracy improved from 0.65010 to 0.67348, saving model to 256_model.h5
# 63/63 [==============================] - 74s 1s/step - loss: 0.9438 - accuracy: 0.6781 - val_loss: 0.9982 - val_accuracy: 0.6735
# Epoch 7/40
# 63/63 [==============================] - ETA: 0s - loss: 0.8888 - accuracy: 0.6976
# Epoch 7: val_accuracy improved from 0.67348 to 0.67634, saving model to 256_model.h5
# 63/63 [==============================] - 74s 1s/step - loss: 0.8888 - accuracy: 0.6976 - val_loss: 0.9630 - val_accuracy: 0.6763
# Epoch 8/40
# 63/63 [==============================] - ETA: 0s - loss: 0.8532 - accuracy: 0.7174
# Epoch 8: val_accuracy improved from 0.67634 to 0.68220, saving model to 256_model.h5
# 63/63 [==============================] - 75s 1s/step - loss: 0.8532 - accuracy: 0.7174 - val_loss: 0.9399 - val_accuracy: 0.6822
# Epoch 9/40
# 63/63 [==============================] - ETA: 0s - loss: 0.7866 - accuracy: 0.7453
# Epoch 9: val_accuracy did not improve from 0.68220
# 63/63 [==============================] - 70s 1s/step - loss: 0.7866 - accuracy: 0.7453 - val_loss: 0.9714 - val_accuracy: 0.6719
# Epoch 10/40
# 63/63 [==============================] - ETA: 0s - loss: 0.7370 - accuracy: 0.7661
# Epoch 10: val_accuracy improved from 0.68220 to 0.74594, saving model to 256_model.h5
# 63/63 [==============================] - 77s 1s/step - loss: 0.7370 - accuracy: 0.7661 - val_loss: 0.7818 - val_accuracy: 0.7459
# Epoch 11/40
# 63/63 [==============================] - ETA: 0s - loss: 0.6948 - accuracy: 0.7813
# Epoch 11: val_accuracy improved from 0.74594 to 0.75736, saving model to 256_model.h5
# 63/63 [==============================] - 75s 1s/step - loss: 0.6948 - accuracy: 0.7813 - val_loss: 0.7572 - val_accuracy: 0.7574
# Epoch 12/40
# 63/63 [==============================] - ETA: 0s - loss: 0.6901 - accuracy: 0.7809
# Epoch 12: val_accuracy improved from 0.75736 to 0.75743, saving model to 256_model.h5
# 63/63 [==============================] - 75s 1s/step - loss: 0.6901 - accuracy: 0.7809 - val_loss: 0.7691 - val_accuracy: 0.7574
# Epoch 13/40
# 63/63 [==============================] - ETA: 0s - loss: 0.6425 - accuracy: 0.7988
# Epoch 13: val_accuracy improved from 0.75743 to 0.76508, saving model to 256_model.h5
# 63/63 [==============================] - 75s 1s/step - loss: 0.6425 - accuracy: 0.7988 - val_loss: 0.7398 - val_accuracy: 0.7651
# Epoch 14/40
# 63/63 [==============================] - ETA: 0s - loss: 0.6298 - accuracy: 0.8023
# Epoch 14: val_accuracy improved from 0.76508 to 0.76834, saving model to 256_model.h5
# 63/63 [==============================] - 76s 1s/step - loss: 0.6298 - accuracy: 0.8023 - val_loss: 0.7636 - val_accuracy: 0.7683
# Epoch 15/40
# 63/63 [==============================] - ETA: 0s - loss: 0.6065 - accuracy: 0.8098
# Epoch 15: val_accuracy did not improve from 0.76834
# 63/63 [==============================] - 70s 1s/step - loss: 0.6065 - accuracy: 0.8098 - val_loss: 0.7382 - val_accuracy: 0.7631
# Epoch 16/40
# 63/63 [==============================] - ETA: 0s - loss: 0.5826 - accuracy: 0.8168
# Epoch 16: val_accuracy improved from 0.76834 to 0.78710, saving model to 256_model.h5
# 63/63 [==============================] - 74s 1s/step - loss: 0.5826 - accuracy: 0.8168 - val_loss: 0.6877 - val_accuracy: 0.7871
# Epoch 17/40
# 63/63 [==============================] - ETA: 0s - loss: 0.5621 - accuracy: 0.8240
# Epoch 17: val_accuracy did not improve from 0.78710
# 63/63 [==============================] - 70s 1s/step - loss: 0.5621 - accuracy: 0.8240 - val_loss: 0.6889 - val_accuracy: 0.7835
# Epoch 18/40
# 63/63 [==============================] - ETA: 0s - loss: 0.5483 - accuracy: 0.8271
# Epoch 18: val_accuracy improved from 0.78710 to 0.79693, saving model to 256_model.h5
# 63/63 [==============================] - 74s 1s/step - loss: 0.5483 - accuracy: 0.8271 - val_loss: 0.6463 - val_accuracy: 0.7969
# Epoch 19/40
# 63/63 [==============================] - ETA: 0s - loss: 0.5367 - accuracy: 0.8316
# Epoch 19: val_accuracy did not improve from 0.79693
# 63/63 [==============================] - 70s 1s/step - loss: 0.5367 - accuracy: 0.8316 - val_loss: 0.6632 - val_accuracy: 0.7921
# Epoch 20/40
# 63/63 [==============================] - ETA: 0s - loss: 0.5384 - accuracy: 0.8303
# Epoch 20: val_accuracy did not improve from 0.79693
# 63/63 [==============================] - 70s 1s/step - loss: 0.5384 - accuracy: 0.8303 - val_loss: 0.6725 - val_accuracy: 0.7893
# Epoch 21/40
# 63/63 [==============================] - ETA: 0s - loss: 0.5164 - accuracy: 0.8368
# Epoch 21: val_accuracy did not improve from 0.79693
# 63/63 [==============================] - 70s 1s/step - loss: 0.5164 - accuracy: 0.8368 - val_loss: 0.6732 - val_accuracy: 0.7934
# Epoch 22/40
# 63/63 [==============================] - ETA: 0s - loss: 0.4996 - accuracy: 0.8413
# Epoch 22: val_accuracy improved from 0.79693 to 0.80445, saving model to 256_model.h5
# 63/63 [==============================] - 77s 1s/step - loss: 0.4996 - accuracy: 0.8413 - val_loss: 0.6239 - val_accuracy: 0.8044
# Epoch 23/40
# 63/63 [==============================] - ETA: 0s - loss: 0.4802 - accuracy: 0.8477
# Epoch 23: val_accuracy did not improve from 0.80445
# 63/63 [==============================] - 70s 1s/step - loss: 0.4802 - accuracy: 0.8477 - val_loss: 0.6598 - val_accuracy: 0.7951
# Epoch 24/40
# 63/63 [==============================] - ETA: 0s - loss: 0.4854 - accuracy: 0.8468
# Epoch 24: val_accuracy did not improve from 0.80445
# 63/63 [==============================] - 70s 1s/step - loss: 0.4854 - accuracy: 0.8468 - val_loss: 0.6365 - val_accuracy: 0.8006
# Epoch 25/40
# 63/63 [==============================] - ETA: 0s - loss: 0.4817 - accuracy: 0.8476
# Epoch 25: val_accuracy did not improve from 0.80445
# 63/63 [==============================] - 70s 1s/step - loss: 0.4817 - accuracy: 0.8476 - val_loss: 0.6865 - val_accuracy: 0.7857
# Epoch 26/40
# 63/63 [==============================] - ETA: 0s - loss: 0.4735 - accuracy: 0.8498
# Epoch 26: val_accuracy improved from 0.80445 to 0.80778, saving model to 256_model.h5
# 63/63 [==============================] - 75s 1s/step - loss: 0.4735 - accuracy: 0.8498 - val_loss: 0.6297 - val_accuracy: 0.8078
# Epoch 27/40
# 63/63 [==============================] - ETA: 0s - loss: 0.4363 - accuracy: 0.8611
# Epoch 27: val_accuracy did not improve from 0.80778
# 63/63 [==============================] - 70s 1s/step - loss: 0.4363 - accuracy: 0.8611 - val_loss: 0.6463 - val_accuracy: 0.7993
# Epoch 28/40
# 63/63 [==============================] - ETA: 0s - loss: 0.4278 - accuracy: 0.8637
# Epoch 28: val_accuracy did not improve from 0.80778
# 63/63 [==============================] - 70s 1s/step - loss: 0.4278 - accuracy: 0.8637 - val_loss: 0.6364 - val_accuracy: 0.8008
# Epoch 29/40
# 63/63 [==============================] - ETA: 0s - loss: 0.4202 - accuracy: 0.8661
# Epoch 29: val_accuracy did not improve from 0.80778
# 63/63 [==============================] - 70s 1s/step - loss: 0.4202 - accuracy: 0.8661 - val_loss: 0.6350 - val_accuracy: 0.8060
# Epoch 30/40
# 63/63 [==============================] - ETA: 0s - loss: 0.4083 - accuracy: 0.8691
# Epoch 30: val_accuracy did not improve from 0.80778
# 63/63 [==============================] - 70s 1s/step - loss: 0.4083 - accuracy: 0.8691 - val_loss: 0.6656 - val_accuracy: 0.7902
# Epoch 31/40
# 63/63 [==============================] - ETA: 0s - loss: 0.4040 - accuracy: 0.8710
# Epoch 31: val_accuracy improved from 0.80778 to 0.80852, saving model to 256_model.h5
# 63/63 [==============================] - 76s 1s/step - loss: 0.4040 - accuracy: 0.8710 - val_loss: 0.6541 - val_accuracy: 0.8085
# Epoch 32/40
# 63/63 [==============================] - ETA: 0s - loss: 0.3917 - accuracy: 0.8753
# Epoch 32: val_accuracy improved from 0.80852 to 0.81214, saving model to 256_model.h5
# 63/63 [==============================] - 75s 1s/step - loss: 0.3917 - accuracy: 0.8753 - val_loss: 0.6270 - val_accuracy: 0.8121
# Epoch 33/40
# 63/63 [==============================] - ETA: 0s - loss: 0.3822 - accuracy: 0.8781
# Epoch 33: val_accuracy did not improve from 0.81214
# 63/63 [==============================] - 70s 1s/step - loss: 0.3822 - accuracy: 0.8781 - val_loss: 0.6446 - val_accuracy: 0.8053
# Epoch 34/40
# 63/63 [==============================] - ETA: 0s - loss: 0.3647 - accuracy: 0.8829
# Epoch 34: val_accuracy did not improve from 0.81214
# 63/63 [==============================] - 70s 1s/step - loss: 0.3647 - accuracy: 0.8829 - val_loss: 0.6485 - val_accuracy: 0.8073
# Epoch 35/40
# 63/63 [==============================] - ETA: 0s - loss: 0.3596 - accuracy: 0.8847
# Epoch 35: val_accuracy did not improve from 0.81214
# 63/63 [==============================] - 70s 1s/step - loss: 0.3596 - accuracy: 0.8847 - val_loss: 0.6444 - val_accuracy: 0.8077
# Epoch 36/40
# 63/63 [==============================] - ETA: 0s - loss: 0.3548 - accuracy: 0.8858
# Epoch 36: val_accuracy did not improve from 0.81214
# 63/63 [==============================] - 70s 1s/step - loss: 0.3548 - accuracy: 0.8858 - val_loss: 0.6490 - val_accuracy: 0.8066
# Epoch 37/40
# 63/63 [==============================] - ETA: 0s - loss: 0.3528 - accuracy: 0.8869
# Epoch 37: val_accuracy did not improve from 0.81214
# 63/63 [==============================] - 70s 1s/step - loss: 0.3528 - accuracy: 0.8869 - val_loss: 0.6773 - val_accuracy: 0.7973
# Epoch 38/40
# 63/63 [==============================] - ETA: 0s - loss: 0.3326 - accuracy: 0.8929
# Epoch 38: val_accuracy improved from 0.81214 to 0.81309, saving model to 256_model.h5
# 63/63 [==============================] - 76s 1s/step - loss: 0.3326 - accuracy: 0.8929 - val_loss: 0.6421 - val_accuracy: 0.8131
# Epoch 39/40
# 63/63 [==============================] - ETA: 0s - loss: 0.3212 - accuracy: 0.8965
# Epoch 39: val_accuracy did not improve from 0.81309
# 63/63 [==============================] - 71s 1s/step - loss: 0.3212 - accuracy: 0.8965 - val_loss: 0.6528 - val_accuracy: 0.8055
# Epoch 40/40
# 63/63 [==============================] - ETA: 0s - loss: 0.3134 - accuracy: 0.8990
# Epoch 40: val_accuracy improved from 0.81309 to 0.81319, saving model to 256_model.h5
# 63/63 [==============================] - 74s 1s/step - loss: 0.3134 - accuracy: 0.8990 - val_loss: 0.6487 - val_accuracy: 0.8132

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# Plot Learning Curves

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.savefig("256 Image Size Experiment/256 Loss Graph")
plt.show()

# %%
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.legend()
plt.savefig("256 Image Size Experiment/256 Accuracy Graph")
plt.show()
